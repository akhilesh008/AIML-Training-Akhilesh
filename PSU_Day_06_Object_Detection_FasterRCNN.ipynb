# %% [markdown]
# <a href="https://colab.research.google.com/github/akhilesh008/AIML-Training-Akhilesh/blob/main/PSU_Day_06_Object_Detection_FasterRCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Object Detection
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# <hr/>
# Object detection is a computer vision and image processing related technique that deals with detecting instances of semantic objects in an image or video. Unlike image classification where labeling object is sufficient object detection involves identifying the position and the boundaries of an object, and only then classifying it into the corresponding categories.

# %% [markdown]
# <hr/>
# <b>Dataset:</b> In this project we are dealing with fruit images dataset. The dataset include the pictures of fruits as well as the `.xml` files that among other things describe the ground truth bounding box coordinates around the objects.
# <br/>
# <b>The main question of the project is:</b> Given the training images with ground truth bounding boxes can we detect fruits in unseen images?
#
# <b>Methods and Findings:</b> We are leveraging an object detection model known as Faster R-CNN to detect our fruits. In order to be able to utilize the model we are creating a dataset class to capture the images and preprocess them. The results are fed into the model.
#
# 1. Create a dataset class to read and preprocess the data.
#
# 2. Define our model with corresponding attributes.
#
# 3. Track the model's performance.

# %%
# !pip install -q torch_snippets lovely-tensors torchinfo

from torch_snippets import *
from IPython import display
import matplotlib.pyplot as plt
import matplotlib.patches as patches
display.set_matplotlib_formats('svg')

from torchinfo import summary

import torch
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from xml.etree import ElementTree as et

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 20.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 34.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 50.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 55.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.9/172.9 kB 19.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 105.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 48.8 MB/s eta 0:00:00
#   Building wheel for typing (setup.py) ... done
# <ipython-input-5-cc479dfa927a>:7: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   display.set_matplotlib_formats('svg')

# %%
# unzip the dataset
# !mkdir dataset
# !unzip -q test_zip.zip -d ./dataset
# !unzip -q train_zip.zip -d ./dataset

# %% [markdown]
# # Reading the Data 📖

# %% [markdown]
# The data is not big. It contains $240$ images of fruits in the train folder and $60$ images in the test folder.
# At this part of the project we will:
# - retrieve the images
# - resize them
# - retrieve the objects labels for each image
# - retrieve the ground truth bounding boxes of the objects for each image
# - resize them accordingly

# %%
root = '/content/dataset/train/'

# we have four labels
labels = ['background', 'orange', 'apple', 'banana']
label2targets = {l: t for t, l in enumerate(labels)}
targets2label = {t: l for l, t in label2targets.items()}
num_classes = len(targets2label)

# %%
def plot_img_bbox(img, target):
    fig, a = plt.subplots(1,1)
    fig.set_size_inches(5,5)
    a.imshow(img)
    for box in target:
        x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
        rect = patches.Rectangle((x, y),
                                 width, height,
                                 linewidth = 2,
                                 edgecolor = 'r',
                                 facecolor = 'none')

        a.add_patch(rect)
    plt.show()

# %%
def preprocess_img(img):
    img = torch.tensor(img).permute(2, 0 ,1)
    return img.float()

class FruitsDataset(Dataset):
    def __init__(self, root=root, transforms=None):
        self.root = root
        self.transforms = transforms
        self.img_paths = sorted(Glob(self.root + '/*.jpg'))
        self.xlm_paths = sorted(Glob(self.root + '/*.xml'))

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        w, h = 224, 224
        img_path = self.img_paths[idx]
        xlm_path = self.xlm_paths[idx]
        img = Image.open(img_path).convert('RGB')
        W, H = img.size
        img = np.array(img.resize((w, h),
                       resample=Image.Resampling.BILINEAR))/255.
        xlm = et.parse(xlm_path)
        objects = xlm.findall('object')
        labels = []
        boxes = []
        # getting BB information from .xml file and converting it into x,y,w,h
        for obj in objects:
            label = obj.find('name').text
            labels.append(label)
            XMin = float(obj.find('bndbox').find('xmin').text)
            YMin = float(obj.find('bndbox').find('ymin').text)
            XMax = float(obj.find('bndbox').find('xmax').text)
            YMax = float(obj.find('bndbox').find('ymax').text)
            bbox = [XMin / W, YMin / H, XMax / W, YMax / H]
            bbox = (bbox * np.array([w, h, w, h])).astype(np.int16).tolist()
            boxes.append(bbox)
        target = {}
        target['labels'] = torch.tensor([label2targets[label] for label in labels]).long()
        target['boxes'] = torch.tensor(boxes).float()
        img = preprocess_img(img)
        return img, target

    def collate_fn(self, batch):
        return tuple(zip(*batch))

val_root = '/content/dataset/test/'

train_ds = FruitsDataset()
train_dl = DataLoader(train_ds, batch_size=4, shuffle=True, collate_fn=train_ds.collate_fn)

val_ds = FruitsDataset(root=val_root)
val_dl = DataLoader(val_ds, batch_size=2, shuffle=True, collate_fn=val_ds.collate_fn)

img, target = train_ds[10]
plot_img_bbox(img.permute(1,2,0), target['boxes'])

# %% [markdown]
# # Model evaluation 🤖

# %% [markdown]
# Let's try to understand the core phases of the prediction process our model is using:
# 1. Anchor Boxes:
# These serve as a replacement of the selective search based region proposals.
# - <b>Key Idea</b> Typically the majority of the objects have a similar shape e.g. a ground truth bounding box for a person will have a greater height than width.
#  - The inspection of the ground truth bounding boxes of the objects present in the images helps to build a descent idea about the height and the width of the objects.
#  - Albeit, some images can be scaled. This will result in the the distortion of the object's height and width. Hence, an aspect ration $\frac{\text{height}}{\text{width}}$ is computed from the ground truth values for objects of each class.
#  - After completion of the previous two steps we can define the <span style="background-color: green;">anchor boxes</span> with heights and widths representing the majority of objects' bounding boxes within certain class for our dataset.
#
# At this stage we have the anchor boxes of certain height/width for each class of objects. However, how one can use such boxes to detect the objects of those classes in the images?
# The answer is by sliding:
# - Slide each anchor box over an image from top left to bottom right.
#
# 2. Region Proposal Network (RPN)
# We pass the image's crops identified by anchor boxes to the RPN model. It then suggests the likelihood of the crop containing an object.
# - For each possible crop compute the IoU$^*$. Those boxes that have higher IoU then some threshold will get a label that mentions that they contain an object. Others will be labeled $0$.
# All the candidate crops that have small IoU will be discarded while training.
#
# Finally, we can perform non-max supression (since multiple crops can contain the same object) to identify the region candidate that has the highest probability of containing an object and eliminate other region candidates that have a high overlap with it.
#
# At this point we managed to build up bounding boxes that are likely to contain the objects. Are we done? Not yet. We should also predict what kind the class of the object around which the bounding box has been created.
#
# 3. Classification and Regression
# Here we are using something known as RoI pooling layer and pass both the image featured learned from the CNN as well as the candidate bounding boxes to RoI.
# RoI pooling is needed to convert each feature map into a fixed dimension map that onward would be passed to fully connected network (FCN). The conversion goes like this:
#  3.1. Take the feature map and the candidate bounding box (i.e. region proposal).
#  3.2. Divide the candidate bounding box into equal-sized sections. The number of this sections is the same as the dimension of the output.
#  3.3 Do max-pooling for these sections.
#
# So, RoI lets us to form feature maps of fixed size from a list of candidate bounding boxes of different size.
# The remaining is straightforward:
# - Flatten the RoI outputs pass to FCN that predicts:
#
# a) The class of the object.
#
# b) The amount of offset for the candidate bounding box to maximize the IoU with the ground truth.
#
# $^*$Remark: Intersection over Union (IoU) is a measure of accuracy i.e. how overlapping the predicted and actual bounding boxes are
# $$ IoU = \frac{\text{Area of overlapping region}}{\text{Area of combined region}} $$

# %% [markdown]
# <hr/>
# All of this is done behind the scenes. Here we are not going to train the model from scratch and go through all those phases (partly because we don't possess the computational resources to do so). Hence, we will use an already pretrained mode from pytorch library.

# %%
def get_model():
    model = models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    #print(in_features)
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    return model

# test the model
imgs, targets = next(iter(train_dl))
imgs = list(img.to(device) for img in imgs)
targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

model = get_model().to(device)
print(model(imgs, targets))
summary(model, (1,3,224,224))
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:02<00:00, 61.9MB/s]
# {
#     'loss_classifier': tensor grad NllLossBackward0 cuda:0 1.571,
#     'loss_box_reg': tensor grad DivBackward0 cuda:0 0.153,
#     'loss_objectness': tensor grad BinaryCrossEntropyWithLogitsBackward0 cuda:0 0.001,
#     'loss_rpn_box_reg': tensor grad DivBackward0 cuda:0 0.003
# }
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# FasterRCNN                                              [100, 4]                  --
# ├─GeneralizedRCNNTransform: 1-1                         [1, 3, 800, 800]          --
# ├─BackboneWithFPN: 1-2                                  [1, 256, 13, 13]          --
# │    └─IntermediateLayerGetter: 2-1                     [1, 2048, 25, 25]         --
# │    │    └─Conv2d: 3-1                                 [1, 64, 400, 400]         (9,408)
# │    │    └─FrozenBatchNorm2d: 3-2                      [1, 64, 400, 400]         --
# │    │    └─ReLU: 3-3                                   [1, 64, 400, 400]         --
# │    │    └─MaxPool2d: 3-4                              [1, 64, 200, 200]         --
# │    │    └─Sequential: 3-5                             [1, 256, 200, 200]        (212,992)
# │    │    └─Sequential: 3-6                             [1, 512, 100, 100]        1,212,416
# │    │    └─Sequential: 3-7                             [1, 1024, 50, 50]         7,077,888
# │    │    └─Sequential: 3-8                             [1, 2048, 25, 25]         14,942,208
# │    └─FeaturePyramidNetwork: 2-2                       [1, 256, 13, 13]          --
# │    │    └─ModuleList: 3-15                            --                        (recursive)
# │    │    └─ModuleList: 3-16                            --                        (recursive)
# │    │    └─ModuleList: 3-15                            --                        (recursive)
# │    │    └─ModuleList: 3-16                            --                        (recursive)
# │    │    └─ModuleList: 3-15                            --                        (recursive)
# │    │    └─ModuleList: 3-16                            --                        (recursive)
# │    │    └─ModuleList: 3-15                            --                        (recursive)
# │    │    └─ModuleList: 3-16                            --                        (recursive)
# │    │    └─LastLevelMaxPool: 3-17                      [1, 256, 200, 200]        --
# ├─RegionProposalNetwork: 1-3                            [1000, 4]                 --
# │    └─RPNHead: 2-3                                     [1, 3, 200, 200]          --
# │    │    └─Sequential: 3-18                            [1, 256, 200, 200]        590,080
# │    │    └─Conv2d: 3-19                                [1, 3, 200, 200]          771
# │    │    └─Conv2d: 3-20                                [1, 12, 200, 200]         3,084
# │    │    └─Sequential: 3-21                            [1, 256, 100, 100]        (recursive)
# │    │    └─Conv2d: 3-22                                [1, 3, 100, 100]          (recursive)
# │    │    └─Conv2d: 3-23                                [1, 12, 100, 100]         (recursive)
# │    │    └─Sequential: 3-24                            [1, 256, 50, 50]          (recursive)
# │    │    └─Conv2d: 3-25                                [1, 3, 50, 50]            (recursive)
# │    │    └─Conv2d: 3-26                                [1, 12, 50, 50]           (recursive)
# │    │    └─Sequential: 3-27                            [1, 256, 25, 25]          (recursive)
# │    │    └─Conv2d: 3-28                                [1, 3, 25, 25]            (recursive)
# │    │    └─Conv2d: 3-29                                [1, 12, 25, 25]           (recursive)
# │    │    └─Sequential: 3-30                            [1, 256, 13, 13]          (recursive)
# │    │    └─Conv2d: 3-31                                [1, 3, 13, 13]            (recursive)
# │    │    └─Conv2d: 3-32                                [1, 12, 13, 13]           (recursive)
# │    └─AnchorGenerator: 2-4                             [159882, 4]               --
# ├─RoIHeads: 1-4                                         [100, 4]                  --
# │    └─MultiScaleRoIAlign: 2-5                          [1000, 256, 7, 7]         --
# │    └─TwoMLPHead: 2-6                                  [1000, 1024]              --
# │    │    └─Linear: 3-33                                [1000, 1024]              12,846,080
# │    │    └─Linear: 3-34                                [1000, 1024]              1,049,600
# │    └─FastRCNNPredictor: 2-7                           [1000, 4]                 --
# │    │    └─Linear: 3-35                                [1000, 4]                 4,100
# │    │    └─Linear: 3-36                                [1000, 16]                16,400
# =========================================================================================================
# Total params: 41,309,411
# Trainable params: 41,087,011
# Non-trainable params: 222,400
# Total mult-adds (G): 133.98
# =========================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 1483.77
# Params size (MB): 165.24
# Estimated Total Size (MB): 1649.61
# =========================================================================================================

# %%
def train_batch(batch, model, optim):
    model.train()
    imgs, targets = batch
    imgs = list(img.to(device) for img in imgs)
    targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
    optim.zero_grad()
    losses = model(imgs, targets)
    loss = sum(loss for loss in losses.values())
    loss.backward()
    optim.step()
    return loss, losses

@torch.no_grad()
def validate_batch(batch, model, optim):
    model.train()
    imgs, targets = batch
    imgs = list(img.to(device) for img in imgs)
    targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
    optim.zero_grad()
    losses = model(imgs, targets)
    loss = sum(loss for loss in losses.values())
    return loss, losses

model = get_model().to(device)
optim = torch.optim.SGD(model.parameters(), lr=0.005,
                       weight_decay=5e-4, momentum=0.9)

n_epochs = 2
log = Report(n_epochs)
for e in range(n_epochs):
    for i, batch in enumerate(train_dl):
        N = len(train_dl)
        loss, losses = train_batch(batch, model, optim)
        loc_loss, regr_loss, loss_objectness, loss_rpn_box_reg = [losses[k] for k in
                                                                  ['loss_classifier', 'loss_box_reg', 'loss_objectness', 'loss_rpn_box_reg']]
        log.record(e + (i+1)/N, trn_loss=loss.item(), trn_loc_loss=loc_loss.item(),
                   trn_regr_loss=regr_loss.item(), trn_loss_objectness=loss_objectness.item(),
                   trn_loss_rpn_box_reg = loss_rpn_box_reg.item())
    for i, batch in enumerate(val_dl):
        N = len(val_dl)
        loss, losses = validate_batch(batch, model.float(), optim)
        loc_loss, regr_loss, loss_objectness, loss_rpn_box_reg = [losses[k] for k in
                                                                  ['loss_classifier', 'loss_box_reg',
                                                                   'loss_objectness', 'loss_rpn_box_reg']]
        log.record(e + (i+1)/N, val_loss=loss.item(), val_loc_loss=loc_loss.item(),
                   val_regr_loss=regr_loss.item(), val_loss_objectness=loss_objectness.item(),
                   val_loss_rpn_box_reg = loss_rpn_box_reg.item())
    log.report_avgs(e+1)
log.plot_epochs(['trn_loss', 'val_loss'])
# Out:
# EPOCH: 0.017  trn_loss: 1.578  trn_loc_loss: 1.206  trn_regr_loss: 0.351  trn_loss_objectness: 0.010  trn_loss_rpn_box_reg: 0.011  (1.48s - 176.19s remaining)
# EPOCH: 0.033  trn_loss: 0.892  trn_loc_loss: 0.407  trn_regr_loss: 0.477  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.006  (2.27s - 134.03s remaining)
# EPOCH: 0.050  trn_loss: 0.659  trn_loc_loss: 0.304  trn_regr_loss: 0.336  trn_loss_objectness: 0.012  trn_loss_rpn_box_reg: 0.007  (3.07s - 119.69s remaining)
# EPOCH: 0.067  trn_loss: 0.839  trn_loc_loss: 0.441  trn_regr_loss: 0.382  trn_loss_objectness: 0.006  trn_loss_rpn_box_reg: 0.010  (3.86s - 111.88s remaining)
# EPOCH: 0.083  trn_loss: 0.590  trn_loc_loss: 0.323  trn_regr_loss: 0.257  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.008  (4.64s - 106.68s remaining)
# EPOCH: 0.100  trn_loss: 0.500  trn_loc_loss: 0.280  trn_regr_loss: 0.216  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.004  (5.46s - 103.80s remaining)
# EPOCH: 0.117  trn_loss: 0.955  trn_loc_loss: 0.450  trn_regr_loss: 0.478  trn_loss_objectness: 0.016  trn_loss_rpn_box_reg: 0.011  (6.27s - 101.20s remaining)
# EPOCH: 0.133  trn_loss: 0.388  trn_loc_loss: 0.165  trn_regr_loss: 0.210  trn_loss_objectness: 0.011  trn_loss_rpn_box_reg: 0.003  (7.03s - 98.46s remaining)
# EPOCH: 0.150  trn_loss: 0.363  trn_loc_loss: 0.136  trn_regr_loss: 0.216  trn_loss_objectness: 0.007  trn_loss_rpn_box_reg: 0.004  (7.82s - 96.42s remaining)
# EPOCH: 0.167  trn_loss: 0.399  trn_loc_loss: 0.154  trn_regr_loss: 0.234  trn_loss_objectness: 0.007  trn_loss_rpn_box_reg: 0.004  (8.59s - 94.53s remaining)
# EPOCH: 0.183  trn_loss: 0.366  trn_loc_loss: 0.143  trn_regr_loss: 0.205  trn_loss_objectness: 0.012  trn_loss_rpn_box_reg: 0.007  (9.37s - 92.86s remaining)
# EPOCH: 0.200  trn_loss: 0.347  trn_loc_loss: 0.154  trn_regr_loss: 0.180  trn_loss_objectness: 0.010  trn_loss_rpn_box_reg: 0.003  (10.14s - 91.26s remaining)
# EPOCH: 0.217  trn_loss: 0.279  trn_loc_loss: 0.116  trn_regr_loss: 0.152  trn_loss_objectness: 0.008  trn_loss_rpn_box_reg: 0.003  (10.91s - 89.84s remaining)
# EPOCH: 0.233  trn_loss: 0.547  trn_loc_loss: 0.181  trn_regr_loss: 0.338  trn_loss_objectness: 0.010  trn_loss_rpn_box_reg: 0.017  (11.68s - 88.46s remaining)
# EPOCH: 0.250  trn_loss: 0.237  trn_loc_loss: 0.092  trn_regr_loss: 0.134  trn_loss_objectness: 0.005  trn_loss_rpn_box_reg: 0.007  (12.51s - 87.54s remaining)
# EPOCH: 0.267  trn_loss: 0.395  trn_loc_loss: 0.157  trn_regr_loss: 0.217  trn_loss_objectness: 0.014  trn_loss_rpn_box_reg: 0.006  (13.30s - 86.43s remaining)
# EPOCH: 0.283  trn_loss: 0.375  trn_loc_loss: 0.126  trn_regr_loss: 0.235  trn_loss_objectness: 0.012  trn_loss_rpn_box_reg: 0.003  (14.08s - 85.29s remaining)
# EPOCH: 0.300  trn_loss: 0.179  trn_loc_loss: 0.073  trn_regr_loss: 0.089  trn_loss_objectness: 0.013  trn_loss_rpn_box_reg: 0.004  (14.85s - 84.17s remaining)
# EPOCH: 0.317  trn_loss: 0.518  trn_loc_loss: 0.181  trn_regr_loss: 0.329  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.008  (15.64s - 83.15s remaining)
# EPOCH: 0.333  trn_loss: 0.572  trn_loc_loss: 0.191  trn_regr_loss: 0.362  trn_loss_objectness: 0.012  trn_loss_rpn_box_reg: 0.007  (16.46s - 82.31s remaining)
# EPOCH: 0.350  trn_loss: 0.334  trn_loc_loss: 0.127  trn_regr_loss: 0.192  trn_loss_objectness: 0.011  trn_loss_rpn_box_reg: 0.003  (17.27s - 81.41s remaining)
# EPOCH: 0.367  trn_loss: 0.294  trn_loc_loss: 0.106  trn_regr_loss: 0.179  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.005  (18.07s - 80.51s remaining)
# EPOCH: 0.383  trn_loss: 0.444  trn_loc_loss: 0.170  trn_regr_loss: 0.261  trn_loss_objectness: 0.006  trn_loss_rpn_box_reg: 0.006  (18.91s - 79.76s remaining)
# EPOCH: 0.400  trn_loss: 0.212  trn_loc_loss: 0.084  trn_regr_loss: 0.122  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.006  (19.74s - 78.96s remaining)
# EPOCH: 0.417  trn_loss: 0.264  trn_loc_loss: 0.099  trn_regr_loss: 0.161  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.004  (20.58s - 78.21s remaining)
# EPOCH: 0.433  trn_loss: 0.224  trn_loc_loss: 0.077  trn_regr_loss: 0.139  trn_loss_objectness: 0.005  trn_loss_rpn_box_reg: 0.004  (21.38s - 77.31s remaining)
# EPOCH: 0.450  trn_loss: 0.449  trn_loc_loss: 0.159  trn_regr_loss: 0.288  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.003  (22.18s - 76.39s remaining)
# EPOCH: 0.467  trn_loss: 0.220  trn_loc_loss: 0.070  trn_regr_loss: 0.145  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.004  (23.02s - 75.65s remaining)
# EPOCH: 0.483  trn_loss: 0.330  trn_loc_loss: 0.117  trn_regr_loss: 0.203  trn_loss_objectness: 0.004  trn_loss_rpn_box_reg: 0.006  (23.82s - 74.76s remaining)
# EPOCH: 0.500  trn_loss: 0.305  trn_loc_loss: 0.094  trn_regr_loss: 0.205  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.004  (24.61s - 73.84s remaining)
# EPOCH: 0.517  trn_loss: 0.342  trn_loc_loss: 0.141  trn_regr_loss: 0.195  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.005  (25.42s - 72.98s remaining)
# EPOCH: 0.533  trn_loss: 0.345  trn_loc_loss: 0.101  trn_regr_loss: 0.233  trn_loss_objectness: 0.002  trn_loss_rpn_box_reg: 0.009  (26.21s - 72.09s remaining)
# EPOCH: 0.550  trn_loss: 0.254  trn_loc_loss: 0.101  trn_regr_loss: 0.147  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.004  (27.02s - 71.24s remaining)
# EPOCH: 0.567  trn_loss: 0.384  trn_loc_loss: 0.143  trn_regr_loss: 0.233  trn_loss_objectness: 0.004  trn_loss_rpn_box_reg: 0.005  (27.84s - 70.41s remaining)
# EPOCH: 0.583  trn_loss: 0.473  trn_loc_loss: 0.193  trn_regr_loss: 0.265  trn_loss_objectness: 0.006  trn_loss_rpn_box_reg: 0.009  (28.64s - 69.56s remaining)
# EPOCH: 0.600  trn_loss: 0.210  trn_loc_loss: 0.086  trn_regr_loss: 0.122  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.002  (29.45s - 68.72s remaining)
# EPOCH: 0.617  trn_loss: 0.379  trn_loc_loss: 0.115  trn_regr_loss: 0.256  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.006  (30.26s - 67.89s remaining)
# EPOCH: 0.633  trn_loss: 0.239  trn_loc_loss: 0.093  trn_regr_loss: 0.137  trn_loss_objectness: 0.006  trn_loss_rpn_box_reg: 0.002  (31.08s - 67.07s remaining)
# EPOCH: 0.650  trn_loss: 0.264  trn_loc_loss: 0.098  trn_regr_loss: 0.158  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.004  (31.92s - 66.30s remaining)
# EPOCH: 0.667  trn_loss: 0.181  trn_loc_loss: 0.068  trn_regr_loss: 0.110  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.002  (32.78s - 65.56s remaining)
# EPOCH: 0.683  trn_loss: 0.187  trn_loc_loss: 0.072  trn_regr_loss: 0.101  trn_loss_objectness: 0.011  trn_loss_rpn_box_reg: 0.004  (33.67s - 64.87s remaining)
# EPOCH: 0.700  trn_loss: 0.292  trn_loc_loss: 0.079  trn_regr_loss: 0.199  trn_loss_objectness: 0.008  trn_loss_rpn_box_reg: 0.005  (34.50s - 64.08s remaining)
# EPOCH: 0.717  trn_loss: 0.224  trn_loc_loss: 0.063  trn_regr_loss: 0.153  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.008  (35.60s - 63.75s remaining)
# EPOCH: 0.733  trn_loss: 0.250  trn_loc_loss: 0.105  trn_regr_loss: 0.131  trn_loss_objectness: 0.002  trn_loss_rpn_box_reg: 0.013  (36.50s - 63.05s remaining)
# EPOCH: 0.750  trn_loss: 0.583  trn_loc_loss: 0.199  trn_regr_loss: 0.334  trn_loss_objectness: 0.031  trn_loss_rpn_box_reg: 0.019  (37.35s - 62.25s remaining)
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# EPOCH: 0.767  trn_loss: 0.453  trn_loc_loss: 0.123  trn_regr_loss: 0.306  trn_loss_objectness: 0.010  trn_loss_rpn_box_reg: 0.014  (38.17s - 61.40s remaining)
# EPOCH: 0.783  trn_loss: 0.187  trn_loc_loss: 0.074  trn_regr_loss: 0.104  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.007  (39.05s - 60.65s remaining)
# EPOCH: 0.800  trn_loss: 0.366  trn_loc_loss: 0.098  trn_regr_loss: 0.247  trn_loss_objectness: 0.012  trn_loss_rpn_box_reg: 0.008  (39.90s - 59.84s remaining)
# EPOCH: 0.817  trn_loss: 0.203  trn_loc_loss: 0.062  trn_regr_loss: 0.130  trn_loss_objectness: 0.008  trn_loss_rpn_box_reg: 0.003  (40.75s - 59.05s remaining)
# EPOCH: 0.833  trn_loss: 0.155  trn_loc_loss: 0.043  trn_regr_loss: 0.109  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.002  (41.56s - 58.19s remaining)
# EPOCH: 0.850  trn_loss: 0.238  trn_loc_loss: 0.072  trn_regr_loss: 0.155  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.009  (42.37s - 57.33s remaining)
# EPOCH: 0.867  trn_loss: 0.364  trn_loc_loss: 0.106  trn_regr_loss: 0.248  trn_loss_objectness: 0.005  trn_loss_rpn_box_reg: 0.005  (43.18s - 56.47s remaining)
# EPOCH: 0.883  trn_loss: 0.168  trn_loc_loss: 0.056  trn_regr_loss: 0.105  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.003  (43.99s - 55.61s remaining)
# EPOCH: 0.900  trn_loss: 0.303  trn_loc_loss: 0.097  trn_regr_loss: 0.193  trn_loss_objectness: 0.006  trn_loss_rpn_box_reg: 0.008  (44.82s - 54.78s remaining)
# EPOCH: 0.917  trn_loss: 0.200  trn_loc_loss: 0.068  trn_regr_loss: 0.115  trn_loss_objectness: 0.010  trn_loss_rpn_box_reg: 0.006  (45.65s - 53.95s remaining)
# EPOCH: 0.933  trn_loss: 0.142  trn_loc_loss: 0.051  trn_regr_loss: 0.089  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.002  (46.46s - 53.10s remaining)
# EPOCH: 0.950  trn_loss: 0.228  trn_loc_loss: 0.068  trn_regr_loss: 0.146  trn_loss_objectness: 0.002  trn_loss_rpn_box_reg: 0.012  (47.27s - 52.25s remaining)
# EPOCH: 0.967  trn_loss: 0.271  trn_loc_loss: 0.076  trn_regr_loss: 0.190  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.004  (48.13s - 51.45s remaining)
# EPOCH: 0.983  trn_loss: 0.150  trn_loc_loss: 0.043  trn_regr_loss: 0.099  trn_loss_objectness: 0.004  trn_loss_rpn_box_reg: 0.004  (48.97s - 50.63s remaining)
# EPOCH: 1.000  trn_loss: 0.360  trn_loc_loss: 0.104  trn_regr_loss: 0.241  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.011  (49.79s - 49.79s remaining)
# EPOCH: 0.033  val_loss: 0.157  val_loc_loss: 0.039  val_regr_loss: 0.112  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.005  (49.98s - 2949.10s remaining)
# EPOCH: 0.067  val_loss: 0.414  val_loc_loss: 0.150  val_regr_loss: 0.259  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.005  (50.17s - 1454.80s remaining)
# EPOCH: 0.100  val_loss: 0.082  val_loc_loss: 0.031  val_regr_loss: 0.049  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.002  (50.36s - 956.78s remaining)
# EPOCH: 0.133  val_loss: 0.451  val_loc_loss: 0.127  val_regr_loss: 0.306  val_loss_objectness: 0.012  val_loss_rpn_box_reg: 0.006  (50.54s - 707.54s remaining)
# EPOCH: 0.167  val_loss: 0.147  val_loc_loss: 0.043  val_regr_loss: 0.092  val_loss_objectness: 0.010  val_loss_rpn_box_reg: 0.002  (50.72s - 557.88s remaining)
# EPOCH: 0.200  val_loss: 0.318  val_loc_loss: 0.097  val_regr_loss: 0.197  val_loss_objectness: 0.010  val_loss_rpn_box_reg: 0.014  (50.91s - 458.17s remaining)
# EPOCH: 0.233  val_loss: 0.379  val_loc_loss: 0.112  val_regr_loss: 0.249  val_loss_objectness: 0.006  val_loss_rpn_box_reg: 0.011  (51.09s - 386.81s remaining)
# EPOCH: 0.267  val_loss: 0.174  val_loc_loss: 0.084  val_regr_loss: 0.083  val_loss_objectness: 0.004  val_loss_rpn_box_reg: 0.003  (51.27s - 333.24s remaining)
# EPOCH: 0.300  val_loss: 0.109  val_loc_loss: 0.041  val_regr_loss: 0.066  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.002  (51.47s - 291.67s remaining)
# EPOCH: 0.333  val_loss: 0.148  val_loc_loss: 0.055  val_regr_loss: 0.089  val_loss_objectness: 0.003  val_loss_rpn_box_reg: 0.002  (51.66s - 258.32s remaining)
# EPOCH: 0.367  val_loss: 0.062  val_loc_loss: 0.017  val_regr_loss: 0.037  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.006  (51.87s - 231.08s remaining)
# EPOCH: 0.400  val_loss: 0.180  val_loc_loss: 0.087  val_regr_loss: 0.083  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.009  (52.05s - 208.19s remaining)
# EPOCH: 0.433  val_loss: 0.072  val_loc_loss: 0.028  val_regr_loss: 0.040  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.003  (52.29s - 189.05s remaining)
# EPOCH: 0.467  val_loss: 0.169  val_loc_loss: 0.042  val_regr_loss: 0.121  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.005  (52.46s - 172.38s remaining)
# EPOCH: 0.500  val_loss: 0.088  val_loc_loss: 0.040  val_regr_loss: 0.040  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.006  (52.68s - 158.03s remaining)
# EPOCH: 0.533  val_loss: 0.287  val_loc_loss: 0.070  val_regr_loss: 0.189  val_loss_objectness: 0.021  val_loss_rpn_box_reg: 0.007  (52.87s - 145.38s remaining)
# EPOCH: 0.567  val_loss: 0.073  val_loc_loss: 0.033  val_regr_loss: 0.038  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.001  (53.04s - 134.17s remaining)
# EPOCH: 0.600  val_loss: 0.561  val_loc_loss: 0.187  val_regr_loss: 0.350  val_loss_objectness: 0.014  val_loss_rpn_box_reg: 0.009  (53.24s - 124.23s remaining)
# EPOCH: 0.633  val_loss: 0.231  val_loc_loss: 0.059  val_regr_loss: 0.141  val_loss_objectness: 0.023  val_loss_rpn_box_reg: 0.008  (53.42s - 115.27s remaining)
# EPOCH: 0.667  val_loss: 0.468  val_loc_loss: 0.116  val_regr_loss: 0.319  val_loss_objectness: 0.023  val_loss_rpn_box_reg: 0.010  (53.61s - 107.21s remaining)
# EPOCH: 0.700  val_loss: 0.086  val_loc_loss: 0.019  val_regr_loss: 0.063  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.001  (53.81s - 99.93s remaining)
# EPOCH: 0.733  val_loss: 0.090  val_loc_loss: 0.030  val_regr_loss: 0.058  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.001  (53.98s - 93.24s remaining)
# EPOCH: 0.767  val_loss: 0.254  val_loc_loss: 0.082  val_regr_loss: 0.161  val_loss_objectness: 0.006  val_loss_rpn_box_reg: 0.005  (54.20s - 87.19s remaining)
# EPOCH: 0.800  val_loss: 0.327  val_loc_loss: 0.119  val_regr_loss: 0.203  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.004  (54.38s - 81.57s remaining)
# EPOCH: 0.833  val_loss: 0.199  val_loc_loss: 0.066  val_regr_loss: 0.129  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.004  (54.60s - 76.45s remaining)
# EPOCH: 0.867  val_loss: 0.225  val_loc_loss: 0.067  val_regr_loss: 0.130  val_loss_objectness: 0.012  val_loss_rpn_box_reg: 0.016  (54.78s - 71.64s remaining)
# EPOCH: 0.900  val_loss: 0.216  val_loc_loss: 0.081  val_regr_loss: 0.129  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.004  (54.98s - 67.20s remaining)
# EPOCH: 0.933  val_loss: 0.332  val_loc_loss: 0.078  val_regr_loss: 0.227  val_loss_objectness: 0.013  val_loss_rpn_box_reg: 0.014  (55.17s - 63.05s remaining)
# EPOCH: 0.967  val_loss: 0.265  val_loc_loss: 0.097  val_regr_loss: 0.157  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.010  (55.37s - 59.19s remaining)
# EPOCH: 1.000  val_loss: 0.201  val_loc_loss: 0.087  val_regr_loss: 0.103  val_loss_objectness: 0.009  val_loss_rpn_box_reg: 0.002  (55.55s - 55.55s remaining)
# EPOCH: 1.000  trn_loss_rpn_box_reg: 0.006  val_loss: 0.226  trn_loss: 0.374  trn_loc_loss: 0.154  val_loss_rpn_box_reg: 0.006  trn_regr_loss: 0.209  val_loss_objectness: 0.006  trn_loss_objectness: 0.006  val_loc_loss: 0.072  val_regr_loss: 0.142  (55.55s - 55.55s remaining)
# EPOCH: 1.017  trn_loss: 0.170  trn_loc_loss: 0.050  trn_regr_loss: 0.115  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.004  (56.35s - 54.50s remaining)
# EPOCH: 1.033  trn_loss: 0.267  trn_loc_loss: 0.076  trn_regr_loss: 0.176  trn_loss_objectness: 0.005  trn_loss_rpn_box_reg: 0.011  (57.19s - 53.50s remaining)
# EPOCH: 1.050  trn_loss: 0.197  trn_loc_loss: 0.062  trn_regr_loss: 0.125  trn_loss_objectness: 0.002  trn_loss_rpn_box_reg: 0.008  (58.03s - 52.50s remaining)
# EPOCH: 1.067  trn_loss: 0.217  trn_loc_loss: 0.057  trn_regr_loss: 0.149  trn_loss_objectness: 0.004  trn_loss_rpn_box_reg: 0.007  (58.87s - 51.51s remaining)
# EPOCH: 1.083  trn_loss: 0.259  trn_loc_loss: 0.067  trn_regr_loss: 0.181  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.008  (59.76s - 50.57s remaining)
# EPOCH: 1.100  trn_loss: 0.241  trn_loc_loss: 0.102  trn_regr_loss: 0.132  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.004  (60.58s - 49.57s remaining)
# EPOCH: 1.117  trn_loss: 0.323  trn_loc_loss: 0.096  trn_regr_loss: 0.212  trn_loss_objectness: 0.005  trn_loss_rpn_box_reg: 0.010  (61.40s - 48.57s remaining)
# EPOCH: 1.133  trn_loss: 0.106  trn_loc_loss: 0.036  trn_regr_loss: 0.064  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.004  (62.31s - 47.65s remaining)
# EPOCH: 1.150  trn_loss: 0.217  trn_loc_loss: 0.059  trn_regr_loss: 0.154  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.004  (63.09s - 46.63s remaining)
# EPOCH: 1.167  trn_loss: 0.176  trn_loc_loss: 0.058  trn_regr_loss: 0.111  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.005  (63.91s - 45.65s remaining)
# EPOCH: 1.183  trn_loss: 0.174  trn_loc_loss: 0.058  trn_regr_loss: 0.107  trn_loss_objectness: 0.005  trn_loss_rpn_box_reg: 0.003  (64.69s - 44.64s remaining)
# EPOCH: 1.200  trn_loss: 0.152  trn_loc_loss: 0.047  trn_regr_loss: 0.100  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.002  (65.53s - 43.68s remaining)
# EPOCH: 1.217  trn_loss: 0.141  trn_loc_loss: 0.053  trn_regr_loss: 0.077  trn_loss_objectness: 0.007  trn_loss_rpn_box_reg: 0.004  (66.32s - 42.70s remaining)
# EPOCH: 1.233  trn_loss: 0.309  trn_loc_loss: 0.084  trn_regr_loss: 0.217  trn_loss_objectness: 0.002  trn_loss_rpn_box_reg: 0.006  (67.11s - 41.72s remaining)
# EPOCH: 1.250  trn_loss: 0.245  trn_loc_loss: 0.107  trn_regr_loss: 0.126  trn_loss_objectness: 0.010  trn_loss_rpn_box_reg: 0.003  (67.91s - 40.74s remaining)
# EPOCH: 1.267  trn_loss: 0.161  trn_loc_loss: 0.051  trn_regr_loss: 0.103  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.007  (68.69s - 39.77s remaining)
# EPOCH: 1.283  trn_loss: 0.143  trn_loc_loss: 0.044  trn_regr_loss: 0.094  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.004  (69.48s - 38.80s remaining)
# EPOCH: 1.300  trn_loss: 0.075  trn_loc_loss: 0.020  trn_regr_loss: 0.053  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.002  (70.27s - 37.84s remaining)
# EPOCH: 1.317  trn_loss: 0.390  trn_loc_loss: 0.129  trn_regr_loss: 0.249  trn_loss_objectness: 0.006  trn_loss_rpn_box_reg: 0.005  (71.07s - 36.88s remaining)
# EPOCH: 1.333  trn_loss: 0.074  trn_loc_loss: 0.025  trn_regr_loss: 0.047  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.002  (71.86s - 35.93s remaining)
# EPOCH: 1.350  trn_loss: 0.121  trn_loc_loss: 0.043  trn_regr_loss: 0.076  trn_loss_objectness: 0.002  trn_loss_rpn_box_reg: 0.001  (72.64s - 34.97s remaining)
# EPOCH: 1.367  trn_loss: 0.189  trn_loc_loss: 0.053  trn_regr_loss: 0.133  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.003  (73.44s - 34.03s remaining)
# EPOCH: 1.383  trn_loss: 0.102  trn_loc_loss: 0.033  trn_regr_loss: 0.065  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.003  (74.27s - 33.11s remaining)
# EPOCH: 1.400  trn_loss: 0.141  trn_loc_loss: 0.047  trn_regr_loss: 0.081  trn_loss_objectness: 0.009  trn_loss_rpn_box_reg: 0.003  (75.10s - 32.19s remaining)
# EPOCH: 1.417  trn_loss: 0.244  trn_loc_loss: 0.070  trn_regr_loss: 0.153  trn_loss_objectness: 0.013  trn_loss_rpn_box_reg: 0.008  (75.93s - 31.27s remaining)
# EPOCH: 1.433  trn_loss: 0.205  trn_loc_loss: 0.053  trn_regr_loss: 0.144  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.005  (76.74s - 30.34s remaining)
# EPOCH: 1.450  trn_loss: 0.135  trn_loc_loss: 0.034  trn_regr_loss: 0.096  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.005  (77.53s - 29.41s remaining)
# EPOCH: 1.467  trn_loss: 0.335  trn_loc_loss: 0.108  trn_regr_loss: 0.205  trn_loss_objectness: 0.005  trn_loss_rpn_box_reg: 0.018  (78.31s - 28.48s remaining)
# EPOCH: 1.483  trn_loss: 0.195  trn_loc_loss: 0.045  trn_regr_loss: 0.139  trn_loss_objectness: 0.008  trn_loss_rpn_box_reg: 0.004  (79.09s - 27.55s remaining)
# EPOCH: 1.500  trn_loss: 0.279  trn_loc_loss: 0.084  trn_regr_loss: 0.176  trn_loss_objectness: 0.007  trn_loss_rpn_box_reg: 0.012  (79.87s - 26.62s remaining)
# EPOCH: 1.517  trn_loss: 0.258  trn_loc_loss: 0.083  trn_regr_loss: 0.159  trn_loss_objectness: 0.010  trn_loss_rpn_box_reg: 0.007  (80.66s - 25.70s remaining)
# EPOCH: 1.533  trn_loss: 0.205  trn_loc_loss: 0.067  trn_regr_loss: 0.134  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.002  (81.46s - 24.79s remaining)
# EPOCH: 1.550  trn_loss: 0.139  trn_loc_loss: 0.043  trn_regr_loss: 0.091  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.003  (82.26s - 23.88s remaining)
# EPOCH: 1.567  trn_loss: 0.169  trn_loc_loss: 0.048  trn_regr_loss: 0.119  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.002  (83.08s - 22.98s remaining)
# EPOCH: 1.583  trn_loss: 0.119  trn_loc_loss: 0.044  trn_regr_loss: 0.073  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.002  (83.88s - 22.07s remaining)
# EPOCH: 1.600  trn_loss: 0.176  trn_loc_loss: 0.042  trn_regr_loss: 0.130  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.003  (84.66s - 21.17s remaining)
# EPOCH: 1.617  trn_loss: 0.189  trn_loc_loss: 0.059  trn_regr_loss: 0.123  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.004  (85.45s - 20.26s remaining)
# EPOCH: 1.633  trn_loss: 0.276  trn_loc_loss: 0.080  trn_regr_loss: 0.188  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.008  (86.24s - 19.36s remaining)
# EPOCH: 1.650  trn_loss: 0.212  trn_loc_loss: 0.052  trn_regr_loss: 0.147  trn_loss_objectness: 0.004  trn_loss_rpn_box_reg: 0.009  (87.07s - 18.47s remaining)
# EPOCH: 1.667  trn_loss: 0.224  trn_loc_loss: 0.056  trn_regr_loss: 0.160  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.007  (87.90s - 17.58s remaining)
# EPOCH: 1.683  trn_loss: 0.073  trn_loc_loss: 0.020  trn_regr_loss: 0.051  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.002  (88.72s - 16.69s remaining)
# EPOCH: 1.700  trn_loss: 0.129  trn_loc_loss: 0.041  trn_regr_loss: 0.085  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.003  (89.51s - 15.80s remaining)
# EPOCH: 1.717  trn_loss: 0.263  trn_loc_loss: 0.074  trn_regr_loss: 0.185  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.004  (90.34s - 14.91s remaining)
# EPOCH: 1.733  trn_loss: 0.230  trn_loc_loss: 0.067  trn_regr_loss: 0.154  trn_loss_objectness: 0.004  trn_loss_rpn_box_reg: 0.005  (91.13s - 14.02s remaining)
# EPOCH: 1.750  trn_loss: 0.078  trn_loc_loss: 0.025  trn_regr_loss: 0.048  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.002  (91.91s - 13.13s remaining)
# EPOCH: 1.767  trn_loss: 0.082  trn_loc_loss: 0.024  trn_regr_loss: 0.056  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.001  (92.68s - 12.24s remaining)
# EPOCH: 1.783  trn_loss: 0.136  trn_loc_loss: 0.047  trn_regr_loss: 0.085  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.004  (93.69s - 11.38s remaining)
# EPOCH: 1.800  trn_loss: 0.128  trn_loc_loss: 0.029  trn_regr_loss: 0.098  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.001  (94.48s - 10.50s remaining)
# EPOCH: 1.817  trn_loss: 0.282  trn_loc_loss: 0.084  trn_regr_loss: 0.193  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.004  (95.26s - 9.61s remaining)
# EPOCH: 1.833  trn_loss: 0.184  trn_loc_loss: 0.071  trn_regr_loss: 0.111  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.002  (96.06s - 8.73s remaining)
# EPOCH: 1.850  trn_loss: 0.084  trn_loc_loss: 0.021  trn_regr_loss: 0.062  trn_loss_objectness: 0.000  trn_loss_rpn_box_reg: 0.001  (96.87s - 7.85s remaining)
# EPOCH: 1.867  trn_loss: 0.293  trn_loc_loss: 0.072  trn_regr_loss: 0.211  trn_loss_objectness: 0.004  trn_loss_rpn_box_reg: 0.006  (97.67s - 6.98s remaining)
# EPOCH: 1.883  trn_loss: 0.169  trn_loc_loss: 0.061  trn_regr_loss: 0.103  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.003  (98.52s - 6.10s remaining)
# EPOCH: 1.900  trn_loss: 0.285  trn_loc_loss: 0.095  trn_regr_loss: 0.184  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.005  (99.31s - 5.23s remaining)
# EPOCH: 1.917  trn_loss: 0.102  trn_loc_loss: 0.028  trn_regr_loss: 0.072  trn_loss_objectness: 0.001  trn_loss_rpn_box_reg: 0.001  (100.13s - 4.35s remaining)
# EPOCH: 1.933  trn_loss: 0.185  trn_loc_loss: 0.043  trn_regr_loss: 0.136  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.004  (100.93s - 3.48s remaining)
# EPOCH: 1.950  trn_loss: 0.115  trn_loc_loss: 0.045  trn_regr_loss: 0.065  trn_loss_objectness: 0.004  trn_loss_rpn_box_reg: 0.001  (101.76s - 2.61s remaining)
# EPOCH: 1.967  trn_loss: 0.324  trn_loc_loss: 0.095  trn_regr_loss: 0.219  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.008  (102.57s - 1.74s remaining)
# EPOCH: 1.983  trn_loss: 0.265  trn_loc_loss: 0.075  trn_regr_loss: 0.178  trn_loss_objectness: 0.007  trn_loss_rpn_box_reg: 0.004  (103.38s - 0.87s remaining)
# EPOCH: 2.000  trn_loss: 0.311  trn_loc_loss: 0.094  trn_regr_loss: 0.209  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.004  (104.22s - 0.00s remaining)
# EPOCH: 1.033  val_loss: 0.397  val_loc_loss: 0.117  val_regr_loss: 0.257  val_loss_objectness: 0.008  val_loss_rpn_box_reg: 0.015  (104.44s - 97.70s remaining)
# EPOCH: 1.067  val_loss: 0.082  val_loc_loss: 0.027  val_regr_loss: 0.036  val_loss_objectness: 0.004  val_loss_rpn_box_reg: 0.015  (104.65s - 91.56s remaining)
# EPOCH: 1.100  val_loss: 0.433  val_loc_loss: 0.116  val_regr_loss: 0.294  val_loss_objectness: 0.014  val_loss_rpn_box_reg: 0.008  (104.84s - 85.78s remaining)
# EPOCH: 1.133  val_loss: 0.342  val_loc_loss: 0.115  val_regr_loss: 0.217  val_loss_objectness: 0.004  val_loss_rpn_box_reg: 0.005  (105.04s - 80.33s remaining)
# EPOCH: 1.167  val_loss: 0.135  val_loc_loss: 0.061  val_regr_loss: 0.068  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.005  (105.27s - 75.19s remaining)
# EPOCH: 1.200  val_loss: 0.271  val_loc_loss: 0.087  val_regr_loss: 0.159  val_loss_objectness: 0.015  val_loss_rpn_box_reg: 0.010  (105.46s - 70.31s remaining)
# EPOCH: 1.233  val_loss: 0.175  val_loc_loss: 0.060  val_regr_loss: 0.113  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.002  (105.65s - 65.67s remaining)
# EPOCH: 1.267  val_loss: 0.409  val_loc_loss: 0.113  val_regr_loss: 0.289  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.005  (105.84s - 61.27s remaining)
# EPOCH: 1.300  val_loss: 0.323  val_loc_loss: 0.093  val_regr_loss: 0.221  val_loss_objectness: 0.003  val_loss_rpn_box_reg: 0.006  (106.03s - 57.10s remaining)
# EPOCH: 1.333  val_loss: 0.120  val_loc_loss: 0.053  val_regr_loss: 0.063  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.004  (106.23s - 53.11s remaining)
# EPOCH: 1.367  val_loss: 0.064  val_loc_loss: 0.021  val_regr_loss: 0.037  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.004  (106.44s - 49.33s remaining)
# EPOCH: 1.400  val_loss: 0.100  val_loc_loss: 0.044  val_regr_loss: 0.055  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.001  (106.62s - 45.70s remaining)
# EPOCH: 1.433  val_loss: 0.318  val_loc_loss: 0.100  val_regr_loss: 0.196  val_loss_objectness: 0.008  val_loss_rpn_box_reg: 0.014  (106.82s - 42.23s remaining)
# EPOCH: 1.467  val_loss: 0.057  val_loc_loss: 0.017  val_regr_loss: 0.038  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.001  (107.04s - 38.92s remaining)
# EPOCH: 1.500  val_loss: 0.200  val_loc_loss: 0.071  val_regr_loss: 0.123  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.006  (107.23s - 35.74s remaining)
# EPOCH: 1.533  val_loss: 0.035  val_loc_loss: 0.011  val_regr_loss: 0.023  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.001  (107.42s - 32.69s remaining)
# EPOCH: 1.567  val_loss: 0.205  val_loc_loss: 0.054  val_regr_loss: 0.145  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.007  (107.61s - 29.76s remaining)
# EPOCH: 1.600  val_loss: 0.185  val_loc_loss: 0.051  val_regr_loss: 0.128  val_loss_objectness: 0.003  val_loss_rpn_box_reg: 0.002  (107.79s - 26.95s remaining)
# EPOCH: 1.633  val_loss: 0.060  val_loc_loss: 0.014  val_regr_loss: 0.038  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.007  (107.98s - 24.24s remaining)
# EPOCH: 1.667  val_loss: 0.273  val_loc_loss: 0.094  val_regr_loss: 0.169  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.010  (108.16s - 21.63s remaining)
# EPOCH: 1.700  val_loss: 0.163  val_loc_loss: 0.062  val_regr_loss: 0.098  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.002  (108.33s - 19.12s remaining)
# EPOCH: 1.733  val_loss: 0.306  val_loc_loss: 0.110  val_regr_loss: 0.193  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.003  (108.51s - 16.69s remaining)
# EPOCH: 1.767  val_loss: 0.101  val_loc_loss: 0.028  val_regr_loss: 0.063  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.007  (108.69s - 14.35s remaining)
# EPOCH: 1.800  val_loss: 0.046  val_loc_loss: 0.017  val_regr_loss: 0.026  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.002  (108.88s - 12.10s remaining)
# EPOCH: 1.833  val_loss: 0.035  val_loc_loss: 0.009  val_regr_loss: 0.025  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.001  (109.06s - 9.91s remaining)
# EPOCH: 1.867  val_loss: 0.312  val_loc_loss: 0.103  val_regr_loss: 0.202  val_loss_objectness: 0.003  val_loss_rpn_box_reg: 0.004  (109.26s - 7.80s remaining)
# EPOCH: 1.900  val_loss: 0.058  val_loc_loss: 0.015  val_regr_loss: 0.035  val_loss_objectness: 0.008  val_loss_rpn_box_reg: 0.001  (109.44s - 5.76s remaining)
# EPOCH: 1.933  val_loss: 0.245  val_loc_loss: 0.082  val_regr_loss: 0.158  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.003  (109.65s - 3.78s remaining)
# EPOCH: 1.967  val_loss: 0.035  val_loc_loss: 0.012  val_regr_loss: 0.022  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.001  (109.84s - 1.86s remaining)
# EPOCH: 2.000  val_loss: 0.136  val_loc_loss: 0.061  val_regr_loss: 0.073  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.002  (110.01s - 0.00s remaining)
# EPOCH: 2.000  trn_loss_rpn_box_reg: 0.005  val_loss: 0.189  trn_loss: 0.195  trn_loc_loss: 0.059  val_loss_rpn_box_reg: 0.005  trn_regr_loss: 0.129  val_loss_objectness: 0.003  trn_loss_objectness: 0.003  val_loc_loss: 0.061  val_regr_loss: 0.120  (110.01s - 0.00s remaining)
# 100%|██████████| 103/103 [00:00<00:00, 14276.71it/s]

# %% [markdown]
# # Model Testing ⚡

# %%
from torchvision.ops import nms

def decode_output(output):
    bbs = output['boxes'].cpu().detach().numpy().astype(np.uint16)
    labels = np.array([targets2label[i] for i in output['labels'].cpu().detach().numpy()])
    confs = output['scores'].cpu().detach().numpy()
    idxs = nms(torch.tensor(bbs.astype(np.float32)), torch.tensor(confs), 0.05)
    bbs, confs, labels = [tensor[idxs] for tensor in [bbs, confs, labels]]
    if len(idxs) == 1:
        bbs, confs, labels = [np.array([tensor]) for tensor in [bbs, confs, labels]]
    return bbs.tolist(), confs.tolist(), labels.tolist()

model.eval()
for i, (images, targets) in enumerate(val_dl):
    imgs = list(img.to(device) for img in images)
    targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
    if i == 3: break
    images = [im for im in imgs]
    outputs = model(images)
    for i, output in enumerate(outputs):
        bbs, confs, labels = decode_output(output)
        plot_img_bbox(images[i].cpu().permute(1,2,0), bbs)

# %% [markdown]
# ### Segmentation

# %% [markdown]
# - Standard Model for Segmentation can be found here:
#   - https://github.com/qubvel/segmentation_models.pytorch.
#   - Walkthrough
# - YOLOv8
#   - Detection and Segmentation
#   - https://github.com/ultralytics/ultralytics
#   - Segment: https://docs.ultralytics.com/tasks/segment/
#   - Detect: https://docs.ultralytics.com/tasks/detect/

# %% [markdown]
# ## Resources worth Read:
# 1. Segmentation Survey Paper: https://ieeexplore.ieee.org/document/9356353
# 2. Detection Blog: https://viso.ai/deep-learning/object-detection/
# 3. A Comprehensive Study of Real-Time Object Detection Networks Across Multiple Domains: A Survey - https://arxiv.org/abs/2208.10895
# 4. Object Detection: https://ieeexplore.ieee.org/document/10028728
# 5. YOLO:https://www.datacamp.com/blog/yolo-object-detection-explained
# 6. Loss Functions: https://github.com/JunMa11/SegLoss
# 7. Loss Functions: https://learnopencv.com/iou-loss-functions-object-detection/

# %% [markdown]
# **Vision Foundation Model in Segmentation**:
# - SAM: Segment Anything Model
# - AI model from Meta AI that can "cut out" any object, in any image, with a single click.
# - SAM produces high-quality object masks from input prompts such as points or boxes, and it can be used to generate object masks for any image.
# - The model is designed and trained to be promptable, so it can transfer zero-shot to new image distributions and tasks.
# - SAM uses a variety of input prompts, including points or boxes, to segment objects in images.
# - The Segment Anything project also includes the Segment Anything Dataset, which is the largest ever segmentation dataset, with over 1 billion masks on 11M licensed and privacy-respecting images.
# - SAM is a starting point for foundation models for image segmentation, and it can reduce the need for task-specific modeling expertise, training compute, and custom data annotation for image segmentation.
#
# - Project: https://segment-anything.com/
